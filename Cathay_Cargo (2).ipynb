# %%
# !pip install requests pandas flask
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.0.6)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
CATHAY_API_KEY= "0Ws2MAmAseTl39JZLohswZZgWLCxpZ1K"
FLIGHTRADAR_API_KEY= "9d6c7a70-9d0a-47e7-8465-a02ed7b2ba74|pFSlNSLYamshmQ9QB6OKlX3UsndCbAkqkAOPLLdvf10d3cdf"

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
import requests
import pandas as pd


# API endpoint
url = "https://fr24api.flightradar24.com/api/live/flight-positions/full"

# Headers with the API key
headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept-Version': 'v1'
}

# Query parameters to filter flights departing from HKG
params = {
    'airports': 'HKG',
    'categories': 'C'  # Assuming the API supports a 'cargo' filter
}

# Send the GET request to the API endpoint
response = requests.get(url, headers=headers, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse JSON data
    data = response.json().get("data", [])

    # Convert the JSON data to a DataFrame
    df = pd.DataFrame(data)

    # Check if the DataFrame has data
    if not df.empty:
        # Display the DataFrame
        print(df)
    else:
        print("No cargo flight data available from HKG.")
else:
    print("Failed to fetch data from API. Status code:", response.status_code)
# Out:
#      fr24_id  flight callsign       lat        lon  track    alt  gspeed  \
# 0   37df0802  LH8470  GEC8470  41.49071   38.33438    113  37000     522
# 1   37df6aaa    5X58    UPS58  21.19379 -162.16924    268  38000     465
# 2   37dde617  5Y9193  GTI9193  24.74538  154.52328    261  40000     476
# 3   37debddb   3S580   BOX580  25.38358  121.78313    228  40000     432
# 4   37df4df9  CX3254  CPA3254  27.72768  120.76304    283  39100     435
# 5   37df1104   D0520   DHK520  41.83434   39.83214     92  37000     521
# 6   37df406a  TK6134  THY6134  40.74112   57.47186     70  39000     573
# 7   37df2645   RH365   HKC365  46.01540   22.49210    116  39000     488
# 8   37df6a5e   LD768   AHK768  26.28819  113.44773    358  39100     466
# 9   37de67b6  SQ7921  SIA7921  49.38974  158.69913    232  40000     408
# 10  37de3f44    CX85   CPA085  37.62636  141.13908    230  40000     384
# 11  37dee566  QR8058  QTR8058  27.86819  105.66526    145  41100     240
# 12  37dec754  QF7526  QFA7526  -7.14318  129.24106    163  37000     487
# 13  37df7225  T84705  TVR4705  26.99932   50.91952    104  39000     510
# 14  37deadc0   KF853   ABB853  23.22011   78.77357    270  38000     467
# 15  37df5913  EK9786  UAE9786  24.01653   62.33332     94  41000     491
# 16  37def0c6   3S514   BOX514  22.99676   83.65595     93  39000     505
# 17  37de5129   5Y343   GTI343  60.53374 -165.57681    260  36000     482
# 18  37ddda5d     5X1     UPS1  42.41713   31.32338    285  36000     454
# 19  37df7041  CX3116  CPA3116  12.94208   82.57996    106  37000     481
#
#     vspeed squawk  ...     hex  type     reg painted_as operating_as  \
# 0        0   7656  ...  3C70CC  B77L  D-ALFL        GEC          GEC
# 1        0   3701  ...  A7FF6A  B748  N614UP        UPS          UPS
# 2        0      0  ...  A55E46  B744  N445MC        GTI          GTI
# 3        0   4157  ...  3C458F  B77L  D-AALO        DHK          BOX
# 4      -64   5727  ...  780218  B744   B-LIB        CPA          CPA
# 5        0   0731  ...  408142  B77L  G-DHMC        DHK          DHK
# 6        0   6764  ...  4BA9F6  A332  TC-JOV        THY          THY
# 7      -64   5260  ...  780A1E  A332   B-LNY        HKC          HKC
# 8      -64   3353  ...  789278  A333   B-LDY        DHK          AHK
# 9        0   7260  ...  76CCD1  B744  9V-SFQ        SIA          SIA
# 10       0   3744  ...  780A6E  B748   B-LJK        CPA          CPA
# 11       0   3422  ...  06A30C  B77L  A7-BFY        QTR          QTR
# 12       0      0  ...  7C1469  A332  VH-EBF        QFA          EFA
# 13       0   4251  ...  504E70  B744  ER-BYK        TVR          TVR
# 14       0   5366  ...  440B9C  A332  OE-LAL       None          ABB
# 15       0   0570  ...  4B8466  B744  TC-ACF        RUN          RUN
# 16       0   4023  ...  3C4583  B77L  D-AALC        BOX          BOX
# 17       0   6565  ...  A972EE  B77L  N708GT       None          GTI
# 18    -128   3203  ...  A8397C  B748  N629UP        UPS          UPS
# 19      64   0621  ...  78021B  B744   B-LIE        CPA          CPA
#
#    orig_iata orig_icao dest_iata dest_icao                   eta
# 0        FRA      EDDF       HKG      VHHH  2024-11-07T04:28:48Z
# 1        HNL      PHNL       HKG      VHHH  2024-11-07T06:24:00Z
# 2        LAS      KLAS       HKG      VHHH  2024-11-07T01:06:15Z
# 3        ICN      RKSI       HKG      VHHH  2024-11-06T21:31:22Z
# 4        HKG      VHHH       PVG      ZSPD  2024-11-06T20:52:16Z
# 5        LEJ      EDDP       HKG      VHHH  2024-11-07T04:16:00Z
# 6        TBS      UGTB       HKG      VHHH  2024-11-07T02:44:16Z
# 7        STN      EGSS       HKG      VHHH  2024-11-07T06:09:04Z
# 8        HKG      VHHH       PEK      ZBAA  2024-11-06T22:13:20Z
# 9        ANC      PANC       HKG      VHHH  2024-11-07T02:59:12Z
# 10       ANC      PANC       HKG      VHHH  2024-11-07T00:44:48Z
# 11       ALA      UAAA       HKG      VHHH  2024-11-06T21:37:04Z
# 12       HKG      VHHH       SYD      YSSY  2024-11-07T00:34:08Z
# 13       RUH      OERK       HKG      VHHH  2024-11-07T03:00:13Z
# 14       HKG      VHHH       DWC      OMDW  2024-11-06T23:11:27Z
# 15       DWC      OMDW       HKG      VHHH  2024-11-07T02:20:48Z
# 16       DXB      OMDB       HKG      VHHH  2024-11-06T23:40:39Z
# 17       ORD      KORD       HKG      VHHH  2024-11-07T05:24:16Z
# 18       HKG      VHHH       CGN      EDDK  2024-11-06T22:45:20Z
# 19       MAA      VOMM       HKG      VHHH  2024-11-07T00:06:24Z
#
# [20 rows x 22 columns]

# %%
# prompt: make two dataframes , one with flight code with CX and the other with the rest

cx_flights = df[df['flight'].str.startswith('CX')]
cx_flights = cx_flights[df['orig_iata'].str.startswith("HKG")]
other_flights = df[~df['flight'].str.startswith('CX')]
other_flights = other_flights[df['orig_iata'].str.startswith("HKG")]
print (cx_flights)
print (other_flights)
# Out:
#     fr24_id  flight callsign       lat        lon  track    alt  gspeed  \
# 4  37df4df9  CX3254  CPA3254  27.72768  120.76304    283  39100     435
#
#    vspeed squawk  ...     hex  type    reg painted_as operating_as orig_iata  \
# 4     -64   5727  ...  780218  B744  B-LIB        CPA          CPA       HKG
#
#   orig_icao dest_iata dest_icao                   eta
# 4      VHHH       PVG      ZSPD  2024-11-06T20:52:16Z
#
# [1 rows x 22 columns]
#      fr24_id  flight callsign       lat        lon  track    alt  gspeed  \
# 8   37df6a5e   LD768   AHK768  26.28819  113.44773    358  39100     466
# 12  37dec754  QF7526  QFA7526  -7.14318  129.24106    163  37000     487
# 14  37deadc0   KF853   ABB853  23.22011   78.77357    270  38000     467
# 18  37ddda5d     5X1     UPS1  42.41713   31.32338    285  36000     454
#
#     vspeed squawk  ...     hex  type     reg painted_as operating_as  \
# 8      -64   3353  ...  789278  A333   B-LDY        DHK          AHK
# 12       0      0  ...  7C1469  A332  VH-EBF        QFA          EFA
# 14       0   5366  ...  440B9C  A332  OE-LAL       None          ABB
# 18    -128   3203  ...  A8397C  B748  N629UP        UPS          UPS
#
#    orig_iata orig_icao dest_iata dest_icao                   eta
# 8        HKG      VHHH       PEK      ZBAA  2024-11-06T22:13:20Z
# 12       HKG      VHHH       SYD      YSSY  2024-11-07T00:34:08Z
# 14       HKG      VHHH       DWC      OMDW  2024-11-06T23:11:27Z
# 18       HKG      VHHH       CGN      EDDK  2024-11-06T22:45:20Z
#
# [4 rows x 22 columns]
# <ipython-input-118-c2555c367f2e>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cx_flights = cx_flights[df['orig_iata'].str.startswith("HKG")]
# <ipython-input-118-c2555c367f2e>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   other_flights = other_flights[df['orig_iata'].str.startswith("HKG")]

# %%
import requests

params = {
  'access_key': '678e422b8b1e322f1d337cb79c7efe2c',
  'flight_status': 'cancelled',
  'dep_iata': 'HKG'
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

# %%
# prompt: make a dataframe from apiresponse

import pandas as pd

# Assuming 'api_response' contains the JSON data from the AviationStack API
# Replace this with your actual API response data if it's different.

# Example API response data (replace with your actual data)



# Check if the API response contains data
if 'data' in api_response and api_response['data']:
    # Create a Pandas DataFrame
    df_aviationstack = pd.DataFrame(api_response['data'])

else:
    print("No flight data found in the API response.")

# %%
print(df_aviationstack)
# Out:
#    flight_date flight_status  \
# 0   2024-11-07     cancelled
# 1   2024-11-07     cancelled
# 2   2024-11-06     cancelled
# 3   2024-11-06     cancelled
# 4   2024-11-06     cancelled
# 5   2024-11-06     cancelled
# 6   2024-11-06     cancelled
# 7   2024-11-06     cancelled
# 8   2024-11-06     cancelled
# 9   2024-11-05        landed
# 10  2024-11-05     cancelled
# 11  2024-11-05     cancelled
# 12  2024-11-05     cancelled
# 13  2024-11-05     cancelled
#
#                                             departure  \
# 0   {'airport': 'Hong Kong International', 'timezo...
# 1   {'airport': 'Hong Kong International', 'timezo...
# 2   {'airport': 'Hong Kong International', 'timezo...
# 3   {'airport': 'Hong Kong International', 'timezo...
# 4   {'airport': 'Hong Kong International', 'timezo...
# 5   {'airport': 'Hong Kong International', 'timezo...
# 6   {'airport': 'Hong Kong International', 'timezo...
# 7   {'airport': 'Hong Kong International', 'timezo...
# 8   {'airport': 'Hong Kong International', 'timezo...
# 9   {'airport': 'Hong Kong International', 'timezo...
# 10  {'airport': 'Hong Kong International', 'timezo...
# 11  {'airport': 'Hong Kong International', 'timezo...
# 12  {'airport': 'Hong Kong International', 'timezo...
# 13  {'airport': 'Hong Kong International', 'timezo...
#
#                                               arrival  \
# 0   {'airport': 'Hangzhou', 'timezone': 'Asia/Shan...
# 1   {'airport': 'Hangzhou', 'timezone': 'Asia/Shan...
# 2   {'airport': 'Shanghai Hongqiao International',...
# 3   {'airport': 'Taiwan Taoyuan International (Chi...
# 4   {'airport': 'Taiwan Taoyuan International (Chi...
# 5   {'airport': 'Beijing Daxing International Airp...
# 6   {'airport': 'Beijing Daxing International Airp...
# 7   {'airport': 'Xiamen', 'timezone': 'Asia/Shangh...
# 8   {'airport': 'Shanghai Hongqiao International',...
# 9   {'airport': 'Beijing Capital International', '...
# 10  {'airport': 'Beijing Capital International', '...
# 11  {'airport': 'Wuxi', 'timezone': 'Asia/Shanghai...
# 12  {'airport': 'Nanjing Lukou International Airpo...
# 13  {'airport': 'Nanjing Lukou International Airpo...
#
#                                               airline  \
# 0   {'name': 'Hainan Airlines', 'iata': 'HU', 'ica...
# 1   {'name': 'Hong Kong Airlines', 'iata': 'HX', '...
# 2   {'name': 'Hainan Airlines', 'iata': 'HU', 'ica...
# 3   {'name': 'Greater Bay Airlines', 'iata': 'HB',...
# 4   {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 5   {'name': 'Hainan Airlines', 'iata': 'HU', 'ica...
# 6   {'name': 'Hong Kong Airlines', 'iata': 'HX', '...
# 7   {'name': 'United Airlines', 'iata': 'UA', 'ica...
# 8   {'name': 'Hong Kong Airlines', 'iata': 'HX', '...
# 9   {'name': 'Hong Kong Airlines', 'iata': 'HX', '...
# 10  {'name': 'Hainan Airlines', 'iata': 'HU', 'ica...
# 11  {'name': 'China Eastern Airlines', 'iata': 'MU...
# 12  {'name': 'Hong Kong Airlines', 'iata': 'HX', '...
# 13  {'name': 'Hainan Airlines', 'iata': 'HU', 'ica...
#
#                                                flight  \
# 0   {'number': '8516', 'iata': 'HU8516', 'icao': '...
# 1   {'number': '112', 'iata': 'HX112', 'icao': 'CR...
# 2   {'number': '8193', 'iata': 'HU8193', 'icao': '...
# 3   {'number': '704', 'iata': 'HB704', 'icao': 'HG...
# 4   {'number': '464', 'iata': 'CX464', 'icao': 'CP...
# 5   {'number': '8085', 'iata': 'HU8085', 'icao': '...
# 6   {'number': '308', 'iata': 'HX308', 'icao': 'CR...
# 7   {'number': '3878', 'iata': 'UA3878', 'icao': '...
# 8   {'number': '258', 'iata': 'HX258', 'icao': 'CR...
# 9   {'number': '312', 'iata': 'HX312', 'icao': 'CR...
# 10  {'number': '8192', 'iata': 'HU8192', 'icao': '...
# 11  {'number': '2902', 'iata': 'MU2902', 'icao': '...
# 12  {'number': '208', 'iata': 'HX208', 'icao': 'CR...
# 13  {'number': '8157', 'iata': 'HU8157', 'icao': '...
#
#                                              aircraft  live
# 0                                                None  None
# 1                                                None  None
# 2                                                None  None
# 3                                                None  None
# 4                                                None  None
# 5                                                None  None
# 6                                                None  None
# 7                                                None  None
# 8                                                None  None
# 9   {'registration': 'B-LPD', 'iata': 'A320', 'ica...  None
# 10                                               None  None
# 11  {'registration': 'B-6803', 'iata': 'A320', 'ic...  None
# 12  {'registration': 'B-LPP', 'iata': 'A320', 'ica...  None
# 13                                               None  None

# %%
the_frame = df_aviationstack['flight'].apply(lambda x: x['iata'])
others = other_flights['flight']
print(the_frame)
print(others)

#print(df.to_dataframe(the_frame))
res = []
for flight in the_frame:
  if flight in others:
    res.append(flight)
print(res)

matched_df_other_flights = pd.DataFrame(columns=df.columns)

# Initialize index
i = 0

# Loop until all values are matched or end of DataFrame is reached
while i < len(res):
    value = res[i]
    matched_rows = other_flights['flight'] == value

    if not matched_rows.empty:
        matched_df_other_flights = pd.concat([matched_df_other_flights, matched_rows], ignore_index=True)

    i += 1
print(matched_df_other_flights)
# Out:
# 0     HU8516
# 1      HX112
# 2     HU8193
# 3      HB704
# 4      CX464
# 5     HU8085
# 6      HX308
# 7     UA3878
# 8      HX258
# 9      HX312
# 10    HU8192
# 11    MU2902
# 12     HX208
# 13    HU8157
# Name: flight, dtype: object
# 8      LD768
# 12    QF7526
# 14     KF853
# 18       5X1
# Name: flight, dtype: object
# []
# Empty DataFrame
# Columns: [fr24_id, flight, callsign, lat, lon, track, alt, gspeed, vspeed, squawk, timestamp, source, hex, type, reg, painted_as, operating_as, orig_iata, orig_icao, dest_iata, dest_icao, eta]
# Index: []
#
# [0 rows x 22 columns]

# %%
params = {
  'access_key': '678e422b8b1e322f1d337cb79c7efe2c',
  'airline_name': 'cathay pacific',
  'dep_iata': 'HKG'
}

api_result_cx = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_cx = api_result_cx.json()

# %%
api_response_cx
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 489},
#  'data': [{'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '1',
#     'delay': 23,
#     'scheduled': '2024-11-07T00:25:00+00:00',
#     'estimated': '2024-11-07T00:25:00+00:00',
#     'actual': '2024-11-07T00:47:00+00:00',
#     'estimated_runway': '2024-11-07T00:47:00+00:00',
#     'actual_runway': '2024-11-07T00:47:00+00:00'},
#    'arrival': {'airport': 'Los Angeles International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'LAX',
#     'icao': 'KLAX',
#     'terminal': 'B',
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2024-11-06T20:55:00+00:00',
#     'estimated': '2024-11-06T20:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '880',
#     'iata': 'CX880',
#     'icao': 'CPA880',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-KPU',
#     'iata': 'B77W',
#     'icao': 'B77W',
#     'icao24': '780A16'},
#    'live': {'updated': '2024-11-06T20:03:01+00:00',
#     'latitude': 35.7095,
#     'longitude': 143.365,
#     'altitude': 10058.4,
#     'direction': 75,
#     'speed_horizontal': 1185.28,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '42',
#     'delay': 15,
#     'scheduled': '2024-11-07T00:25:00+00:00',
#     'estimated': '2024-11-07T00:25:00+00:00',
#     'actual': '2024-11-07T00:39:00+00:00',
#     'estimated_runway': '2024-11-07T00:39:00+00:00',
#     'actual_runway': '2024-11-07T00:39:00+00:00'},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T04:50:00+00:00',
#     'estimated': '2024-11-07T04:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '9201',
#     'iata': 'CX9201',
#     'icao': 'CPA9201',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '815',
#      'flight_iata': 'qr815',
#      'flight_icao': 'qtr815'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '61',
#     'delay': 12,
#     'scheduled': '2024-11-07T00:40:00+00:00',
#     'estimated': '2024-11-07T00:40:00+00:00',
#     'actual': '2024-11-07T00:51:00+00:00',
#     'estimated_runway': '2024-11-07T00:51:00+00:00',
#     'actual_runway': '2024-11-07T00:51:00+00:00'},
#    'arrival': {'airport': 'Zurich',
#     'timezone': 'Europe/Zurich',
#     'iata': 'ZRH',
#     'icao': 'LSZH',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:30:00+00:00',
#     'estimated': '2024-11-07T07:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '383',
#     'iata': 'CX383',
#     'icao': 'CPA383',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LRD',
#     'iata': 'A359',
#     'icao': 'A359',
#     'icao24': '780AA4'},
#    'live': {'updated': '2024-11-06T20:02:47+00:00',
#     'latitude': 38.5883,
#     'longitude': 99.1768,
#     'altitude': 11003.3,
#     'direction': 299,
#     'speed_horizontal': 850.068,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': 10,
#     'scheduled': '2024-11-07T00:40:00+00:00',
#     'estimated': '2024-11-07T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ted Stevens Anchorage International Airport',
#     'timezone': 'America/Anchorage',
#     'iata': 'ANC',
#     'icao': 'PANC',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T17:10:00+00:00',
#     'estimated': '2024-11-06T17:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '3170',
#     'iata': 'CX3170',
#     'icao': 'CPA3170',
#     'codeshared': None},
#    'aircraft': {'registration': 'XXB',
#     'iata': 'B744',
#     'icao': 'B744',
#     'icao24': 'XXC'},
#    'live': {'updated': '2024-11-06T19:28:16+00:00',
#     'latitude': 25.7857,
#     'longitude': 122.843,
#     'altitude': 10050.8,
#     'direction': 49.79,
#     'speed_horizontal': 1018.48,
#     'speed_vertical': 1.188,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '5',
#     'delay': 19,
#     'scheduled': '2024-11-07T00:50:00+00:00',
#     'estimated': '2024-11-07T00:50:00+00:00',
#     'actual': '2024-11-07T01:08:00+00:00',
#     'estimated_runway': '2024-11-07T01:08:00+00:00',
#     'actual_runway': '2024-11-07T01:08:00+00:00'},
#    'arrival': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:40:00+00:00',
#     'estimated': '2024-11-07T07:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '233',
#     'iata': 'CX233',
#     'icao': 'CPA233',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-KPF',
#     'iata': 'B77W',
#     'icao': 'B77W',
#     'icao24': '780212'},
#    'live': {'updated': '2024-11-06T20:02:59+00:00',
#     'latitude': 38.0103,
#     'longitude': 100.512,
#     'altitude': 9784.08,
#     'direction': 299,
#     'speed_horizontal': 850.068,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '41',
#     'delay': 20,
#     'scheduled': '2024-11-07T00:55:00+00:00',
#     'estimated': '2024-11-07T00:55:00+00:00',
#     'actual': '2024-11-07T01:14:00+00:00',
#     'estimated_runway': '2024-11-07T01:14:00+00:00',
#     'actual_runway': '2024-11-07T01:14:00+00:00'},
#    'arrival': {'airport': 'San Francisco International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'SFO',
#     'icao': 'KSFO',
#     'terminal': 'I',
#     'gate': None,
#     'baggage': 'CL7',
#     'delay': None,
#     'scheduled': '2024-11-06T21:15:00+00:00',
#     'estimated': '2024-11-06T21:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '872',
#     'iata': 'CX872',
#     'icao': 'CPA872',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LQC',
#     'iata': 'A359',
#     'icao': 'A359',
#     'icao24': '789243'},
#    'live': {'updated': '2024-11-06T18:26:23+00:00',
#     'latitude': 25.7668,
#     'longitude': 122.818,
#     'altitude': 11277.6,
#     'direction': 49.84,
#     'speed_horizontal': 1025.1,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '36',
#     'delay': 25,
#     'scheduled': '2024-11-07T00:55:00+00:00',
#     'estimated': '2024-11-07T00:55:00+00:00',
#     'actual': '2024-11-07T01:20:00+00:00',
#     'estimated_runway': '2024-11-07T01:20:00+00:00',
#     'actual_runway': '2024-11-07T01:20:00+00:00'},
#    'arrival': {'airport': 'Manchester Airport',
#     'timezone': 'Europe/London',
#     'iata': 'MAN',
#     'icao': 'EGCC',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:55:00+00:00',
#     'estimated': '2024-11-07T07:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '219',
#     'iata': 'CX219',
#     'icao': 'CPA219',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LRO',
#     'iata': 'A359',
#     'icao': 'A359',
#     'icao24': '780ABA'},
#    'live': {'updated': '2024-11-06T20:02:59+00:00',
#     'latitude': 37.3176,
#     'longitude': 102.522,
#     'altitude': 11003.3,
#     'direction': 301,
#     'speed_horizontal': 846.364,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '44',
#     'delay': 25,
#     'scheduled': '2024-11-07T01:00:00+00:00',
#     'estimated': '2024-11-07T01:00:00+00:00',
#     'actual': '2024-11-07T01:25:00+00:00',
#     'estimated_runway': '2024-11-07T01:25:00+00:00',
#     'actual_runway': '2024-11-07T01:25:00+00:00'},
#    'arrival': {'airport': 'Vancouver International',
#     'timezone': 'America/Vancouver',
#     'iata': 'YVR',
#     'icao': 'CYVR',
#     'terminal': 'I',
#     'gate': None,
#     'baggage': '23',
#     'delay': None,
#     'scheduled': '2024-11-06T20:35:00+00:00',
#     'estimated': '2024-11-06T20:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '888',
#     'iata': 'CX888',
#     'icao': 'CPA888',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-KQT',
#     'iata': 'B77W',
#     'icao': 'B77W',
#     'icao24': '780A8D'},
#    'live': {'updated': '2024-11-06T18:29:50+00:00',
#     'latitude': 25.1306,
#     'longitude': 121.99,
#     'altitude': 10058.4,
#     'direction': 49.31,
#     'speed_horizontal': 994.14,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': 48,
#     'scheduled': '2024-11-07T01:05:00+00:00',
#     'estimated': '2024-11-07T01:05:00+00:00',
#     'actual': '2024-11-07T01:53:00+00:00',
#     'estimated_runway': '2024-11-07T01:53:00+00:00',
#     'actual_runway': '2024-11-07T01:53:00+00:00'},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 5,
#     'scheduled': '2024-11-07T06:15:00+00:00',
#     'estimated': '2024-11-07T06:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '6',
#     'iata': 'CX6',
#     'icao': 'CPA6',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LJC',
#     'iata': 'B748',
#     'icao': 'B748',
#     'icao24': '780233'},
#    'live': {'updated': '2024-11-06T18:59:57+00:00',
#     'latitude': 25.3727,
#     'longitude': 122.304,
#     'altitude': 10058.4,
#     'direction': 49.91,
#     'speed_horizontal': 1009.44,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '32',
#     'delay': 18,
#     'scheduled': '2024-11-07T00:25:00+00:00',
#     'estimated': '2024-11-07T00:25:00+00:00',
#     'actual': '2024-11-07T00:43:00+00:00',
#     'estimated_runway': '2024-11-07T00:43:00+00:00',
#     'actual_runway': '2024-11-07T00:43:00+00:00'},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '10',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T12:30:00+00:00',
#     'estimated': '2024-11-07T12:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '105',
#     'iata': 'CX105',
#     'icao': 'CPA105',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LRN',
#     'iata': 'A359',
#     'icao': 'A359',
#     'icao24': '780AB9'},
#    'live': {'updated': '2024-11-06T19:59:33+00:00',
#     'latitude': -0.0292,
#     'longitude': 126.573,
#     'altitude': 11887.2,
#     'direction': 99,
#     'speed_horizontal': 885.256,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '23',
#     'delay': 23,
#     'scheduled': '2024-11-07T00:15:00+00:00',
#     'estimated': '2024-11-07T00:15:00+00:00',
#     'actual': '2024-11-07T00:37:00+00:00',
#     'estimated_runway': '2024-11-07T00:37:00+00:00',
#     'actual_runway': '2024-11-07T00:37:00+00:00'},
#    'arrival': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:05:00+00:00',
#     'estimated': '2024-11-07T07:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '289',
#     'iata': 'CX289',
#     'icao': 'CPA289',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-KPD',
#     'iata': 'B77W',
#     'icao': 'B77W',
#     'icao24': '780204'},
#    'live': {'updated': '2024-11-06T20:02:46+00:00',
#     'latitude': 39.678,
#     'longitude': 96.503,
#     'altitude': 9784.08,
#     'direction': 297,
#     'speed_horizontal': 816.732,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '24',
#     'delay': 31,
#     'scheduled': '2024-11-07T00:15:00+00:00',
#     'estimated': '2024-11-07T00:15:00+00:00',
#     'actual': '2024-11-07T00:45:00+00:00',
#     'estimated_runway': '2024-11-07T00:45:00+00:00',
#     'actual_runway': '2024-11-07T00:45:00+00:00'},
#    'arrival': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:35:00+00:00',
#     'estimated': '2024-11-07T07:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '261',
#     'iata': 'CX261',
#     'icao': 'CPA261',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LRM',
#     'iata': 'A359',
#     'icao': 'A359',
#     'icao24': '780AB8'},
#    'live': {'updated': '2024-11-06T20:02:56+00:00',
#     'latitude': 39.2138,
#     'longitude': 97.6674,
#     'altitude': 11003.3,
#     'direction': 298,
#     'speed_horizontal': 842.66,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '201',
#     'delay': 15,
#     'scheduled': '2024-11-07T02:45:00+00:00',
#     'estimated': '2024-11-07T02:45:00+00:00',
#     'actual': '2024-11-07T03:00:00+00:00',
#     'estimated_runway': '2024-11-07T03:00:00+00:00',
#     'actual_runway': '2024-11-07T03:00:00+00:00'},
#    'arrival': {'airport': 'Jeju Airport',
#     'timezone': 'Asia/Seoul',
#     'iata': 'CJU',
#     'icao': 'RKPC',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T06:40:00+00:00',
#     'estimated': '2024-11-07T06:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5676',
#     'iata': 'CX5676',
#     'icao': 'CPA5676',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '676',
#      'flight_iata': 'uo676',
#      'flight_icao': 'hke676'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': 'E',
#     'delay': None,
#     'scheduled': '2024-11-07T07:05:00+00:00',
#     'estimated': '2024-11-07T07:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': '1',
#     'gate': 'B4',
#     'baggage': '2',
#     'delay': None,
#     'scheduled': '2024-11-07T08:45:00+00:00',
#     'estimated': '2024-11-07T08:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '464',
#     'iata': 'CX464',
#     'icao': 'CPA464',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': 70,
#     'scheduled': '2024-11-07T06:55:00+00:00',
#     'estimated': '2024-11-07T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ted Stevens Anchorage International Airport',
#     'timezone': 'America/Anchorage',
#     'iata': 'ANC',
#     'icao': 'PANC',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T23:25:00+00:00',
#     'estimated': '2024-11-06T23:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '3280',
#     'iata': 'CX3280',
#     'icao': 'CPA3280',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': 2,
#     'scheduled': '2024-11-07T02:55:00+00:00',
#     'estimated': '2024-11-07T02:55:00+00:00',
#     'actual': '2024-11-07T02:56:00+00:00',
#     'estimated_runway': '2024-11-07T02:56:00+00:00',
#     'actual_runway': '2024-11-07T02:56:00+00:00'},
#    'arrival': {'airport': 'Shanghai Pudong International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PVG',
#     'icao': 'ZSPD',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T05:20:00+00:00',
#     'estimated': '2024-11-07T05:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '3254',
#     'iata': 'CX3254',
#     'icao': 'CPA3254',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LIB',
#     'iata': 'B744',
#     'icao': 'B744',
#     'icao24': '780218'},
#    'live': {'updated': '2024-11-06T19:59:43+00:00',
#     'latitude': 26.4936,
#     'longitude': 120.917,
#     'altitude': 11917.7,
#     'direction': 28.41,
#     'speed_horizontal': 953.784,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '2',
#     'delay': 23,
#     'scheduled': '2024-11-07T01:40:00+00:00',
#     'estimated': '2024-11-07T01:40:00+00:00',
#     'actual': '2024-11-07T02:03:00+00:00',
#     'estimated_runway': '2024-11-07T02:03:00+00:00',
#     'actual_runway': '2024-11-07T02:03:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '4',
#     'gate': 'G21',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2024-11-07T05:40:00+00:00',
#     'estimated': '2024-11-07T05:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '659',
#     'iata': 'CX659',
#     'icao': 'CPA659',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LRX',
#     'iata': 'A359',
#     'icao': 'A359',
#     'icao24': '789204'},
#    'live': {'updated': '2024-11-06T19:59:06+00:00',
#     'latitude': 9.6177,
#     'longitude': 106.804,
#     'altitude': 12192,
#     'direction': 213,
#     'speed_horizontal': 898.22,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '28',
#     'delay': 24,
#     'scheduled': '2024-11-07T01:25:00+00:00',
#     'estimated': '2024-11-07T01:25:00+00:00',
#     'actual': '2024-11-07T01:48:00+00:00',
#     'estimated_runway': '2024-11-07T01:48:00+00:00',
#     'actual_runway': '2024-11-07T01:48:00+00:00'},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '2',
#     'gate': '75',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T06:30:00+00:00',
#     'estimated': '2024-11-07T06:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '524',
#     'iata': 'CX524',
#     'icao': 'CPA524',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LXO',
#     'iata': 'A35K',
#     'icao': 'A35K',
#     'icao24': '789247'},
#    'live': {'updated': '2024-11-06T18:59:57+00:00',
#     'latitude': 25.6011,
#     'longitude': 122.602,
#     'altitude': 11277.6,
#     'direction': 49.62,
#     'speed_horizontal': 991.944,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '3',
#     'delay': 19,
#     'scheduled': '2024-11-07T03:20:00+00:00',
#     'estimated': '2024-11-07T03:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'John F Kennedy International',
#     'timezone': 'America/New_York',
#     'iata': 'JFK',
#     'icao': 'KJFK',
#     'terminal': '8',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T05:45:00+00:00',
#     'estimated': '2024-11-07T05:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '844',
#     'iata': 'CX844',
#     'icao': 'CPA844',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '15',
#     'delay': None,
#     'scheduled': '2024-11-07T08:05:00+00:00',
#     'estimated': '2024-11-07T08:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chongqing Jiangbei International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'CKG',
#     'icao': 'ZUCK',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T10:40:00+00:00',
#     'estimated': '2024-11-07T10:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '932',
#     'iata': 'CX932',
#     'icao': 'CPA932',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '29',
#     'delay': None,
#     'scheduled': '2024-11-07T08:00:00+00:00',
#     'estimated': '2024-11-07T08:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': '1',
#     'gate': 'B5',
#     'baggage': '2',
#     'delay': None,
#     'scheduled': '2024-11-07T09:45:00+00:00',
#     'estimated': '2024-11-07T09:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '488',
#     'iata': 'CX488',
#     'icao': 'CPA488',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '8',
#     'delay': None,
#     'scheduled': '2024-11-07T07:50:00+00:00',
#     'estimated': '2024-11-07T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Guangzhou Baiyun International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'CAN',
#     'icao': 'ZGGG',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '48',
#     'delay': None,
#     'scheduled': '2024-11-07T08:55:00+00:00',
#     'estimated': '2024-11-07T08:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '982',
#     'iata': 'CX982',
#     'icao': 'CPA982',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '11',
#     'delay': None,
#     'scheduled': '2024-11-07T07:50:00+00:00',
#     'estimated': '2024-11-07T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Hangzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'HGH',
#     'icao': 'ZSHC',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T10:10:00+00:00',
#     'estimated': '2024-11-07T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '958',
#     'iata': 'CX958',
#     'icao': 'CPA958',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:50:00+00:00',
#     'estimated': '2024-11-07T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T11:55:00+00:00',
#     'estimated': '2024-11-07T11:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '691',
#     'iata': 'CX691',
#     'icao': 'CPA691',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '203',
#     'delay': None,
#     'scheduled': '2024-11-07T07:40:00+00:00',
#     'estimated': '2024-11-07T07:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chiang Mai International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'CNX',
#     'icao': 'VTCC',
#     'terminal': None,
#     'gate': '08I',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2024-11-07T09:50:00+00:00',
#     'estimated': '2024-11-07T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5756',
#     'iata': 'CX5756',
#     'icao': 'CPA5756',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '756',
#      'flight_iata': 'uo756',
#      'flight_icao': 'hke756'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:40:00+00:00',
#     'estimated': '2024-11-07T07:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chingchuankang',
#     'timezone': 'Asia/Taipei',
#     'iata': 'RMQ',
#     'icao': 'RCMQ',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:15:00+00:00',
#     'estimated': '2024-11-07T09:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5192',
#     'iata': 'CX5192',
#     'icao': 'CPA5192',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '192',
#      'flight_iata': 'uo192',
#      'flight_icao': 'hke192'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '213',
#     'delay': None,
#     'scheduled': '2024-11-07T07:35:00+00:00',
#     'estimated': '2024-11-07T07:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T08:50:00+00:00',
#     'estimated': '2024-11-07T08:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5540',
#     'iata': 'CX5540',
#     'icao': 'CPA5540',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '540',
#      'flight_iata': 'uo540',
#      'flight_icao': 'hke540'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '14',
#     'delay': None,
#     'scheduled': '2024-11-07T07:30:00+00:00',
#     'estimated': '2024-11-07T07:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': '3',
#     'gate': 'B',
#     'baggage': '37',
#     'delay': None,
#     'scheduled': '2024-11-07T10:45:00+00:00',
#     'estimated': '2024-11-07T10:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '334',
#     'iata': 'CX334',
#     'icao': 'CPA334',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': 'BC',
#     'delay': None,
#     'scheduled': '2024-11-07T07:30:00+00:00',
#     'estimated': '2024-11-07T07:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:40:00+00:00',
#     'estimated': '2024-11-07T09:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '907',
#     'iata': 'CX907',
#     'icao': 'CPA907',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '28',
#     'delay': None,
#     'scheduled': '2024-11-07T07:30:00+00:00',
#     'estimated': '2024-11-07T07:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Shanghai Pudong International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PVG',
#     'icao': 'ZSPD',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '30',
#     'delay': None,
#     'scheduled': '2024-11-07T10:10:00+00:00',
#     'estimated': '2024-11-07T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '366',
#     'iata': 'CX366',
#     'icao': 'CPA366',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T07:25:00+00:00',
#     'estimated': '2024-11-07T07:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Naha',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'OKA',
#     'icao': 'ROAH',
#     'terminal': 'I',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T10:55:00+00:00',
#     'estimated': '2024-11-07T10:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5820',
#     'iata': 'CX5820',
#     'icao': 'CPA5820',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '820',
#      'flight_iata': 'uo820',
#      'flight_icao': 'hke820'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': 'E',
#     'delay': None,
#     'scheduled': '2024-11-07T09:00:00+00:00',
#     'estimated': '2024-11-07T09:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': '1',
#     'gate': 'B6',
#     'baggage': '2',
#     'delay': None,
#     'scheduled': '2024-11-07T11:00:00+00:00',
#     'estimated': '2024-11-07T11:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '530',
#     'iata': 'CX530',
#     'icao': 'CPA530',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:00:00+00:00',
#     'estimated': '2024-11-07T09:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': '3',
#     'gate': None,
#     'baggage': '35',
#     'delay': None,
#     'scheduled': '2024-11-07T12:30:00+00:00',
#     'estimated': '2024-11-07T12:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '386',
#     'iata': 'CX386',
#     'icao': 'CPA386',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': 'A',
#     'delay': None,
#     'scheduled': '2024-11-07T09:30:00+00:00',
#     'estimated': '2024-11-07T09:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T11:00:00+00:00',
#     'estimated': '2024-11-07T11:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '970',
#     'iata': 'CX970',
#     'icao': 'CPA970',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:30:00+00:00',
#     'estimated': '2024-11-07T09:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'John F Kennedy International',
#     'timezone': 'America/New_York',
#     'iata': 'JFK',
#     'icao': 'KJFK',
#     'terminal': '8',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T12:10:00+00:00',
#     'estimated': '2024-11-07T12:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '830',
#     'iata': 'CX830',
#     'icao': 'CPA830',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:25:00+00:00',
#     'estimated': '2024-11-07T09:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Takamatsu',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'TAK',
#     'icao': 'RJOT',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T13:45:00+00:00',
#     'estimated': '2024-11-07T13:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5642',
#     'iata': 'CX5642',
#     'icao': 'CPA5642',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '642',
#      'flight_iata': 'uo642',
#      'flight_icao': 'hke642'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': 'H',
#     'delay': None,
#     'scheduled': '2024-11-07T09:25:00+00:00',
#     'estimated': '2024-11-07T09:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Beijing Daxing International Airport',
#     'timezone': '+8',
#     'iata': 'PKX',
#     'icao': 'ZBAD',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T13:15:00+00:00',
#     'estimated': '2024-11-07T13:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5260',
#     'iata': 'CX5260',
#     'icao': 'CPA5260',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '260',
#      'flight_iata': 'uo260',
#      'flight_icao': 'hke260'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:20:00+00:00',
#     'estimated': '2024-11-07T09:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '1',
#     'gate': '40',
#     'baggage': '21',
#     'delay': None,
#     'scheduled': '2024-11-07T13:55:00+00:00',
#     'estimated': '2024-11-07T13:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '410',
#     'iata': 'CX410',
#     'icao': 'CPA410',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:20:00+00:00',
#     'estimated': '2024-11-07T09:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Soekarno-Hatta International',
#     'timezone': 'Asia/Jakarta',
#     'iata': 'CGK',
#     'icao': 'WIII',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T13:20:00+00:00',
#     'estimated': '2024-11-07T13:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '777',
#     'iata': 'CX777',
#     'icao': 'CPA777',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-07T09:15:00+00:00',
#     'estimated': '2024-11-07T09:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T13:00:00+00:00',
#     'estimated': '2024-11-07T13:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '43',
#     'iata': 'CX43',
#     'icao': 'CPA43',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-07',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '215',
#     'delay': None,
#     'scheduled': '2024-11-07T09:10:00+00:00',
#     'estimated': '2024-11-07T09:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Gimhae',
#     'timezone': 'Asia/Seoul',
#     'iata': 'PUS',
#     'icao': 'RKPK',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-07T13:20:00+00:00',
#     'estimated': '2024-11-07T13:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5674',
#     'iata': 'CX5674',
#     'icao': 'CPA5674',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '674',
# ...
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2024-11-06T13:00:00+00:00',
#     'estimated': '2024-11-06T13:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T16:10:00+00:00',
#     'estimated': '2024-11-06T16:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '6102',
#     'iata': 'CX6102',
#     'icao': 'CPA6102',
#     'codeshared': {'airline_name': 'air china ltd',
#      'airline_iata': 'ca',
#      'airline_icao': 'cca',
#      'flight_number': '102',
#      'flight_iata': 'ca102',
#      'flight_icao': 'cca102'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '204',
#     'delay': 12,
#     'scheduled': '2024-11-06T13:00:00+00:00',
#     'estimated': '2024-11-06T13:00:00+00:00',
#     'actual': '2024-11-06T13:11:00+00:00',
#     'estimated_runway': '2024-11-06T13:11:00+00:00',
#     'actual_runway': '2024-11-06T13:11:00+00:00'},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '2',
#     'gate': '96',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T18:05:00+00:00',
#     'estimated': '2024-11-06T18:05:00+00:00',
#     'actual': '2024-11-06T17:39:00+00:00',
#     'estimated_runway': '2024-11-06T17:39:00+00:00',
#     'actual_runway': '2024-11-06T17:39:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '5646',
#     'iata': 'CX5646',
#     'icao': 'CPA5646',
#     'codeshared': {'airline_name': 'hong kong express',
#      'airline_iata': 'uo',
#      'airline_icao': 'hke',
#      'flight_number': '646',
#      'flight_iata': 'uo646',
#      'flight_icao': 'hke646'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '511',
#     'delay': 14,
#     'scheduled': '2024-11-06T13:40:00+00:00',
#     'estimated': '2024-11-06T13:40:00+00:00',
#     'actual': '2024-11-06T13:54:00+00:00',
#     'estimated_runway': '2024-11-06T13:54:00+00:00',
#     'actual_runway': '2024-11-06T13:54:00+00:00'},
#    'arrival': {'airport': 'Chengdu Tianfu International Airport',
#     'timezone': 'Asia/Chongqing',
#     'iata': 'TFU',
#     'icao': 'ZUTF',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T16:20:00+00:00',
#     'estimated': '2024-11-06T16:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '6122',
#     'iata': 'CX6122',
#     'icao': 'CPA6122',
#     'codeshared': {'airline_name': 'air china ltd',
#      'airline_iata': 'ca',
#      'airline_icao': 'cca',
#      'flight_number': '412',
#      'flight_iata': 'ca412',
#      'flight_icao': 'cca412'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '70',
#     'delay': 27,
#     'scheduled': '2024-11-06T17:30:00+00:00',
#     'estimated': '2024-11-06T17:30:00+00:00',
#     'actual': '2024-11-06T17:56:00+00:00',
#     'estimated_runway': '2024-11-06T17:56:00+00:00',
#     'actual_runway': '2024-11-06T17:56:00+00:00'},
#    'arrival': {'airport': 'Shanghai Pudong International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PVG',
#     'icao': 'ZSPD',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '30',
#     'delay': None,
#     'scheduled': '2024-11-06T20:15:00+00:00',
#     'estimated': '2024-11-06T20:15:00+00:00',
#     'actual': '2024-11-06T19:57:00+00:00',
#     'estimated_runway': '2024-11-06T19:57:00+00:00',
#     'actual_runway': '2024-11-06T19:57:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '364',
#     'iata': 'CX364',
#     'icao': 'CPA364',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-HLR',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '780192'},
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '43',
#     'delay': 19,
#     'scheduled': '2024-11-06T17:35:00+00:00',
#     'estimated': '2024-11-06T17:35:00+00:00',
#     'actual': '2024-11-06T17:54:00+00:00',
#     'estimated_runway': '2024-11-06T17:54:00+00:00',
#     'actual_runway': '2024-11-06T17:54:00+00:00'},
#    'arrival': {'airport': 'Jinjiang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JJN',
#     'icao': 'ZSQZ',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T19:00:00+00:00',
#     'estimated': '2024-11-06T19:00:00+00:00',
#     'actual': '2024-11-06T18:59:00+00:00',
#     'estimated_runway': '2024-11-06T18:59:00+00:00',
#     'actual_runway': '2024-11-06T18:59:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '6248',
#     'iata': 'CX6248',
#     'icao': 'CPA6248',
#     'codeshared': {'airline_name': 'shenzhen airlines',
#      'airline_iata': 'zh',
#      'airline_icao': 'csz',
#      'flight_number': '9092',
#      'flight_iata': 'zh9092',
#      'flight_icao': 'csz9092'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '42',
#     'delay': 23,
#     'scheduled': '2024-11-06T17:40:00+00:00',
#     'estimated': '2024-11-06T17:40:00+00:00',
#     'actual': '2024-11-06T18:02:00+00:00',
#     'estimated_runway': '2024-11-06T18:02:00+00:00',
#     'actual_runway': '2024-11-06T18:02:00+00:00'},
#    'arrival': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': '13',
#     'delay': None,
#     'scheduled': '2024-11-06T21:35:00+00:00',
#     'estimated': '2024-11-06T21:35:00+00:00',
#     'actual': '2024-11-06T20:48:00+00:00',
#     'estimated_runway': '2024-11-06T20:48:00+00:00',
#     'actual_runway': '2024-11-06T20:48:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '695',
#     'iata': 'CX695',
#     'icao': 'CPA695',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-KQQ',
#     'iata': 'B77W',
#     'icao': 'B77W',
#     'icao24': '780A65'},
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '31',
#     'delay': 32,
#     'scheduled': '2024-11-06T17:50:00+00:00',
#     'estimated': '2024-11-06T17:50:00+00:00',
#     'actual': '2024-11-06T18:22:00+00:00',
#     'estimated_runway': '2024-11-06T18:22:00+00:00',
#     'actual_runway': '2024-11-06T18:22:00+00:00'},
#    'arrival': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': '15',
#     'baggage': '6',
#     'delay': 14,
#     'scheduled': '2024-11-06T19:20:00+00:00',
#     'estimated': '2024-11-06T19:20:00+00:00',
#     'actual': '2024-11-06T19:33:00+00:00',
#     'estimated_runway': '2024-11-06T19:33:00+00:00',
#     'actual_runway': '2024-11-06T19:33:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '978',
#     'iata': 'CX978',
#     'icao': 'CPA978',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-HLW',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '7801B6'},
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '12',
#     'delay': 16,
#     'scheduled': '2024-11-06T17:50:00+00:00',
#     'estimated': '2024-11-06T17:50:00+00:00',
#     'actual': '2024-11-06T18:06:00+00:00',
#     'estimated_runway': '2024-11-06T18:06:00+00:00',
#     'actual_runway': '2024-11-06T18:06:00+00:00'},
#    'arrival': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': '3',
#     'gate': 'B',
#     'baggage': '40',
#     'delay': None,
#     'scheduled': '2024-11-06T21:10:00+00:00',
#     'estimated': '2024-11-06T21:10:00+00:00',
#     'actual': '2024-11-06T20:52:00+00:00',
#     'estimated_runway': '2024-11-06T20:52:00+00:00',
#     'actual_runway': '2024-11-06T20:52:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '6110',
#     'iata': 'CX6110',
#     'icao': 'CPA6110',
#     'codeshared': {'airline_name': 'air china ltd',
#      'airline_iata': 'ca',
#      'airline_icao': 'cca',
#      'flight_number': '110',
#      'flight_iata': 'ca110',
#      'flight_icao': 'cca110'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '69',
#     'delay': 34,
#     'scheduled': '2024-11-06T17:50:00+00:00',
#     'estimated': '2024-11-06T17:50:00+00:00',
#     'actual': '2024-11-06T18:24:00+00:00',
#     'estimated_runway': '2024-11-06T18:24:00+00:00',
#     'actual_runway': '2024-11-06T18:24:00+00:00'},
#    'arrival': {'airport': 'Auckland International',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'AKL',
#     'icao': 'NZAA',
#     'terminal': 'I',
#     'gate': '10',
#     'baggage': 'ITB2',
#     'delay': None,
#     'scheduled': '2024-11-07T09:40:00+00:00',
#     'estimated': '2024-11-07T09:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '7401',
#     'iata': 'CX7401',
#     'icao': 'CPA7401',
#     'codeshared': {'airline_name': 'air new zealand',
#      'airline_iata': 'nz',
#      'airline_icao': 'anz',
#      'flight_number': '80',
#      'flight_iata': 'nz80',
#      'flight_icao': 'anz80'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '61',
#     'delay': 42,
#     'scheduled': '2024-11-06T17:55:00+00:00',
#     'estimated': '2024-11-06T17:55:00+00:00',
#     'actual': '2024-11-06T18:36:00+00:00',
#     'estimated_runway': '2024-11-06T18:36:00+00:00',
#     'actual_runway': '2024-11-06T18:36:00+00:00'},
#    'arrival': {'airport': 'Fuzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'FOC',
#     'icao': 'ZSFZ',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': '1',
#     'delay': 10,
#     'scheduled': '2024-11-06T19:35:00+00:00',
#     'estimated': '2024-11-06T19:35:00+00:00',
#     'actual': '2024-11-06T19:44:00+00:00',
#     'estimated_runway': '2024-11-06T19:44:00+00:00',
#     'actual_runway': '2024-11-06T19:44:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '990',
#     'iata': 'CX990',
#     'icao': 'CPA990',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LAR',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '780A49'},
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '5',
#     'delay': 36,
#     'scheduled': '2024-11-06T18:05:00+00:00',
#     'estimated': '2024-11-06T18:05:00+00:00',
#     'actual': '2024-11-06T18:41:00+00:00',
#     'estimated_runway': '2024-11-06T18:41:00+00:00',
#     'actual_runway': '2024-11-06T18:41:00+00:00'},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2024-11-06T22:30:00+00:00',
#     'estimated': '2024-11-06T22:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '9203',
#     'iata': 'CX9203',
#     'icao': 'CPA9203',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '817',
#      'flight_iata': 'qr817',
#      'flight_icao': 'qtr817'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '2',
#     'delay': 38,
#     'scheduled': '2024-11-06T16:05:00+00:00',
#     'estimated': '2024-11-06T16:05:00+00:00',
#     'actual': '2024-11-06T16:43:00+00:00',
#     'estimated_runway': '2024-11-06T16:43:00+00:00',
#     'actual_runway': '2024-11-06T16:43:00+00:00'},
#    'arrival': {'airport': 'Suvarnabhumi International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'BKK',
#     'icao': 'VTBS',
#     'terminal': '2',
#     'gate': 'G3',
#     'baggage': '21',
#     'delay': None,
#     'scheduled': '2024-11-06T18:15:00+00:00',
#     'estimated': '2024-11-06T18:15:00+00:00',
#     'actual': '2024-11-06T18:14:00+00:00',
#     'estimated_runway': '2024-11-06T18:14:00+00:00',
#     'actual_runway': '2024-11-06T18:14:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '701',
#     'iata': 'CX701',
#     'icao': 'CPA701',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-HLM',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '78018D'},
#    'live': None},
#   {'flight_date': '2024-11-06',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '66',
#     'delay': 20,
#     'scheduled': '2024-11-06T16:00:00+00:00',
#     'estimated': '2024-11-06T16:00:00+00:00',
#     'actual': '2024-11-06T16:20:00+00:00',
#     'estimated_runway': '2024-11-06T16:20:00+00:00',
#     'actual_runway': '2024-11-06T16:20:00+00:00'},
#    'arrival': {'airport': 'Hangzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'HGH',
#     'icao': 'ZSHC',
#     'terminal': '4',
#     'gate': None,
#     'baggage': '28',
#     'delay': None,
#     'scheduled': '2024-11-06T18:15:00+00:00',
#     'estimated': '2024-11-06T18:15:00+00:00',
#     'actual': '2024-11-06T18:13:00+00:00',
#     'estimated_runway': '2024-11-06T18:13:00+00:00',
#     'actual_runway': '2024-11-06T18:13:00+00:00'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '962',
#     'iata': 'CX962',
#     'icao': 'CPA962',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-LAN',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '780A0B'},
#    'live': None}]}

# %%
# prompt: make a dataframe from apiresponse

import pandas as pd

# Assuming 'api_response' contains the JSON data from the AviationStack API
# Replace this with your actual API response data if it's different.

# Example API response data (replace with your actual data)



# Check if the API response contains data
if 'data' in api_response_cx and api_response_cx['data']:
    # Create a Pandas DataFrame
    df_aviationstack_cx = pd.DataFrame(api_response_cx['data'])

else:
    print("No flight data found in the API response.")

print(df_aviationstack_cx)
# Out:
#    flight_date flight_status  \
# 0   2024-11-07        active
# 1   2024-11-07        active
# 2   2024-11-07        active
# 3   2024-11-07        active
# 4   2024-11-07        active
# ..         ...           ...
# 95  2024-11-06        active
# 96  2024-11-06        landed
# 97  2024-11-06        active
# 98  2024-11-06        landed
# 99  2024-11-06        landed
#
#                                             departure  \
# 0   {'airport': 'Hong Kong International', 'timezo...
# 1   {'airport': 'Hong Kong International', 'timezo...
# 2   {'airport': 'Hong Kong International', 'timezo...
# 3   {'airport': 'Hong Kong International', 'timezo...
# 4   {'airport': 'Hong Kong International', 'timezo...
# ..                                                ...
# 95  {'airport': 'Hong Kong International', 'timezo...
# 96  {'airport': 'Hong Kong International', 'timezo...
# 97  {'airport': 'Hong Kong International', 'timezo...
# 98  {'airport': 'Hong Kong International', 'timezo...
# 99  {'airport': 'Hong Kong International', 'timezo...
#
#                                               arrival  \
# 0   {'airport': 'Los Angeles International', 'time...
# 1   {'airport': 'Doha International', 'timezone': ...
# 2   {'airport': 'Zurich', 'timezone': 'Europe/Zuri...
# 3   {'airport': 'Ted Stevens Anchorage Internation...
# 4   {'airport': 'Milano Malpensa', 'timezone': 'Eu...
# ..                                                ...
# 95  {'airport': 'Auckland International', 'timezon...
# 96  {'airport': 'Fuzhou', 'timezone': 'Asia/Shangh...
# 97  {'airport': 'Doha International', 'timezone': ...
# 98  {'airport': 'Suvarnabhumi International', 'tim...
# 99  {'airport': 'Hangzhou', 'timezone': 'Asia/Shan...
#
#                                               airline  \
# 0   {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 1   {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 2   {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 3   {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 4   {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# ..                                                ...
# 95  {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 96  {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 97  {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 98  {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
# 99  {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...
#
#                                                flight  \
# 0   {'number': '880', 'iata': 'CX880', 'icao': 'CP...
# 1   {'number': '9201', 'iata': 'CX9201', 'icao': '...
# 2   {'number': '383', 'iata': 'CX383', 'icao': 'CP...
# 3   {'number': '3170', 'iata': 'CX3170', 'icao': '...
# 4   {'number': '233', 'iata': 'CX233', 'icao': 'CP...
# ..                                                ...
# 95  {'number': '7401', 'iata': 'CX7401', 'icao': '...
# 96  {'number': '990', 'iata': 'CX990', 'icao': 'CP...
# 97  {'number': '9203', 'iata': 'CX9203', 'icao': '...
# 98  {'number': '701', 'iata': 'CX701', 'icao': 'CP...
# 99  {'number': '962', 'iata': 'CX962', 'icao': 'CP...
#
#                                              aircraft  \
# 0   {'registration': 'B-KPU', 'iata': 'B77W', 'ica...
# 1                                                None
# 2   {'registration': 'B-LRD', 'iata': 'A359', 'ica...
# 3   {'registration': 'XXB', 'iata': 'B744', 'icao'...
# 4   {'registration': 'B-KPF', 'iata': 'B77W', 'ica...
# ..                                                ...
# 95                                               None
# 96  {'registration': 'B-LAR', 'iata': 'A333', 'ica...
# 97                                               None
# 98  {'registration': 'B-HLM', 'iata': 'A333', 'ica...
# 99  {'registration': 'B-LAN', 'iata': 'A333', 'ica...
#
#                                                  live
# 0   {'updated': '2024-11-06T20:03:01+00:00', 'lati...
# 1                                                None
# 2   {'updated': '2024-11-06T20:02:47+00:00', 'lati...
# 3   {'updated': '2024-11-06T19:28:16+00:00', 'lati...
# 4   {'updated': '2024-11-06T20:02:59+00:00', 'lati...
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
# [100 rows x 8 columns]

# %%
the_frame = df_aviationstack_cx['flight'].apply(lambda x: x['iata'])
cathay_flights = cx_flights['flight']
print('frame',the_frame)
print('cathay',cathay_flights)
#print(df.to_dataframe(the_frame))
res = []
for flight in the_frame:
  if flight in others:
    res.append(flight)
    print('flight number',flight)
print(res)

matched_df_cx = pd.DataFrame(columns=df.columns)

# Initialize index
i = 0

# Loop until all values are matched or end of DataFrame is reached
while i < len(res):
    value = res[i]
    matched_rows = cx_flights['flight'] == value

    if not matched_rows.empty:
        matched_df_cx = pd.concat([matched_df_cx, matched_rows], ignore_index=True)

    i += 1
print(matched_df_cx)
# Out:
# frame 0      CX880
# 1     CX9201
# 2      CX383
# 3     CX3170
# 4      CX233
#        ...
# 95    CX7401
# 96     CX990
# 97    CX9203
# 98     CX701
# 99     CX962
# Name: flight, Length: 100, dtype: object
# cathay 4    CX3254
# Name: flight, dtype: object
# []
# Empty DataFrame
# Columns: [fr24_id, flight, callsign, lat, lon, track, alt, gspeed, vspeed, squawk, timestamp, source, hex, type, reg, painted_as, operating_as, orig_iata, orig_icao, dest_iata, dest_icao, eta]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Combine the data from the two API responses for Cathay Pacific cargo flights and other flights
combined_df = pd.concat([df_aviationstack, df_aviationstack_cx], ignore_index=True)

# Find the destination airports for the cancelled flights
cancelled_flights_destinations = combined_df[combined_df['flight_status'] == 'cancelled']['arr_iata'].unique()

# Filter out the Cathay Pacific cargo flights departing after the cancelled flight departure to the same destination
matched_cx_flights = matched_df_cx[matched_df_cx['arrival_iata'].isin(cancelled_flights_destinations) & matched_df_cx['departure_time'] > matched_df_other_flights['departure_time'].max()]

print("Cathay Pacific cargo flights departing after the cancelled flight departure to the same destination:")
print(matched_cx_flights)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'arr_iata'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-b06677e943a2> in <cell line: 5>()
#       3
#       4 # Find the destination airports for the cancelled flights
# ----> 5 cancelled_flights_destinations = combined_df[combined_df['flight_status'] == 'cancelled']['arr_iata'].unique()
#       6
#       7 # Filter out the Cathay Pacific cargo flights departing after the cancelled flight departure to the same destination
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'arr_iata'
